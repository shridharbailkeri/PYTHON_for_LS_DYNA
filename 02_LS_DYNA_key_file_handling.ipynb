# %%
from qd.cae.dyna import *

# %%
kf = KeyFile("F:/pythonTimBuchalka/LSTC.FMH.091201_V2.0.k")

# %%
kf.keys()
# Out:
# ['*CONSTRAINED_EXTRA_NODES_SET',
#  '*CONSTRAINED_RIGID_BODIES',
#  '*CONTACT_AUTOMATIC_SURFACE_TO_SURFACE_ID',
#  '*CONTROL_BULK_VISCOSITY',
#  '*DATABASE_HISTORY_NODE',
#  '*DEFINE_COORDINATE_NODES_TITLE',
#  '*ELEMENT_SEATBELT_ACCELEROMETER',
#  '*ELEMENT_SOLID',
#  '*END',
#  '*KEYWORD',
#  '*MAT_OGDEN_RUBBER_TITLE',
#  '*MAT_RIGID_TITLE',
#  '*NODE',
#  '*PART',
#  '*SECTION_SOLID_TITLE',
#  '*SET_NODE_LIST_TITLE',
#  '*TITLE']

# %%
kf2 = KeyFile("F:/masterthesisFE/results/24kmh/std/constyoundlsprestdairbag.k")

# %%
kf2.keys()
# Out:
# ['*AIRBAG_HYBRID_JETTING_CM_ID',
#  '*BOUNDARY_SPC_NODE',
#  '*CONSTRAINED_RIGID_BODIES',
#  '*CONTACT_AIRBAG_SINGLE_SURFACE_ID',
#  '*CONTACT_AUTOMATIC_SURFACE_TO_SURFACE_ID',
#  '*CONTROL_CONTACT',
#  '*CONTROL_ENERGY',
#  '*CONTROL_OUTPUT',
#  '*CONTROL_SHELL',
#  '*CONTROL_TERMINATION',
#  '*CONTROL_TIMESTEP',
#  '*DATABASE_ABSTAT',
#  '*DATABASE_BINARY_D3DUMP',
#  '*DATABASE_BINARY_D3PLOT',
#  '*DATABASE_ELOUT',
#  '*DATABASE_EXTENT_BINARY',
#  '*DATABASE_GLSTAT',
#  '*DATABASE_MATSUM',
#  '*DATABASE_NCFORC',
#  '*DATABASE_NODOUT',
#  '*DATABASE_RWFORC',
#  '*DATABASE_SECFORC',
#  '*DATABASE_SLEOUT',
#  '*DEFINE_CURVE_TITLE',
#  '*DEFINE_FRICTION',
#  '*ELEMENT_SHELL',
#  '*END',
#  '*INCLUDE_TRANSFORM',
#  '*INITIAL_VELOCITY',
#  '*KEYWORD  99999999',
#  '*MAT_FABRIC_TITLE',
#  '*MAT_PIECEWISE_LINEAR_PLASTICITY_TITLE',
#  '*MAT_RIGID_TITLE',
#  '*NODE',
#  '*PARAMETER',
#  '*PART',
#  '*SECTION_SHELL',
#  '*SET_NODE_GENERAL_TITLE',
#  '*SET_PART_LIST_TITLE']

# %%
kf3 = KeyFile("F:/thor/OBLIQUE-THOR-ACCORD-MODEL_to_NHTSA/01_OBLIQUE/01_LEFT_SIDE_IMPACT/25_50_NHTSA_OBLIQUE_L-ACCORD_Full_model.key", load_includes=True)

# %%
kf3.get_includes()

# %%
kw = kf3['*INCLUDE'][0]

# %%
print(kw)
# Out:
# *INCLUDE
# ../../00_INCLUDES/81_CONNECTIONS/AIRBAG_CONNECTIONS_1.k

# %%
print(kf3)
# Out:
# *KEYWORD
# *TITLE
# OBLIQUE_LEFT_IMPACT_THOR_MODEL
# $---+----1----+----2----+----3----+----4----+----5----+----6----+----7----+----8
# $ PARAMETER
# $---+----1----+----2----+----3----+----4----+----5----+----6----+----7----+----8
# *PARAMETER
# $ TIME TO SUB FRAME FAILURE BASED ON THE LOAD CASE
# $ 01_US_NCAP_Full_Frontal = 40.4 ms
# R TFAIL           0.
# R CAW             0.
# R CAF             0.
# R CAR             0.
# $
# $---+----1----+----2----+----3----+----4----+----5----+----6----+----7----+----8
# $ OUTPUT
# $---+----1----+----2----+----3----+----4----+----5----+----6----+----7----+----8
# $
# *DATABASE_EXTENT_BINARY
# $#   NEIPH     NEIPS    MAXINT    STRFLG    SIGFLG    EPSFLG    RLTFLG    ENGFLG
#          0         0         0         0         2         0         2         0
# $#  CMPFLG    IEVERP    BEAMIP     DCOMP      SHGE     STSSZ    N3THDT
#          0         1         0         0         0         3         0
# *DATABASE_BINARY_D3PLOT
#      0.002
# ...

# %%
kw = kf3["*INCLUDE"]

# %%
print(kf3.get_includes()[0])
# Out:
# $
# $ANSA_VERSION;15.3.1;
# $
# $
# $ file created by  A N S A  Thu Apr 13 11:39:31 2017
# $
# $ output from :
# $
# $ /FEA_DATA/K.32501_NHTSA_Oblique_Overlap/modeling/Organizing_Model/01_US_NCAP_F
# $ ULL_FRONTAL/03_TRAIL/Untitled
# $
# *KEYWORD
# $ANSA_COLOR;AIRBAG_CONNECTIONS.k;INCLUDE;.635294139385223;.035294119268656;.0470
# $58824449778;1.;
# $
# $
# $
# *CONSTRAINED_RIGID_BODIES
# $ANSA_ID;81000180;
#   51000008   1000010         0
# $ANSA_NAME_COMMENT;1;WPLANE;X-Y default plane;;NO;YES;NO;
# $ANSA_NAME_COMMENT;2;WPLANE;Y-Z default plane;;NO;YES;NO;
# $ANSA_NAME_COMMENT;3;WPLANE;Z-X default plane;;NO;YES;NO;
# $ANSA_PART;PART;ID;1;NAME;Untitled;STUDY_VERSION;0;PID_OFFSET;0;COLOR;212;44;180
# $;0;IS_COLOR_ACTIVE;1;ATTRIBUTES;41;100_;;1_1_1_08_004_100_;;1_1_1_08_007_100_;;
# $1_1_1_74_002_100_;;1_1_1_75_018_100_;;22MnB5__;;2_1_2_15_001_100_;;5_;;991_501_
# $791_01_TM_CATPart;;991_502_497_00_TM_CATPart;;Aktiv;;CONF_STATUS;;DM/File Type;
# ...

# %%
kw = kf2['*INITIAL_VELOCITY']

# %%
print(kw)
# Out:
# [<Keyword: *INITIAL_VELOCITY>]

# %%
print(kw[0])
# Out:
# *INITIAL_VELOCITY
# $#    nsid    nsidex     boxid    irigid
#    1000000         0         0        -2
# $#      vx        vy        vz       vxr       vyr       vzr
#   -6666.67     0.000     0.000
